# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadbasimkhalid/FirstMLproject/blob/main/Practice_session_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## 1. Importing numpy and pandas (obvious steps).

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## Importing the data from a csv file and saving it in a variable called 'data'

# %%
data=pd.read_csv('train_data.csv')
pd.read_csv('train_data.csv')
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 0       0003HW9UAA  51.0            NaN            87300.0
# 1       000ELHLBPV  37.0        81658.0           152598.0
# 2       000G6CHJON   NaN            NaN            77767.0
# 3       000K09D0JB  54.0        42344.0            13261.0
# 4       000NTH4YTU  63.0        48898.0           193990.0
# ...            ...   ...            ...                ...
# 164140  Q9F1Z6IHR3   NaN       104735.0            46263.0
# 164141  Q9F3V28VP1  32.0        95592.0            89893.0
# 164142  Q9G76RDH0U   NaN        30762.0           232372.0
# 164143  Q9GJOOZ1LF  29.0            NaN            84383.0
# 164144  Q9GM69Z1ZK   NaN            NaN                NaN
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 0                      358.0                            13.0
# 1                      792.0                            23.0
# 2                      359.0                            57.0
# ...

# %% [markdown]
# ## Some important steps to be taken early

# %% [markdown]
# ### looking at the shape of data to analyse the size of data

# %%
#data.shape

# %% [markdown]
# ### looking at sample 5 rows of data to overlook the data

# %%
data.sample(5)
# Out:
#       Investor_ID   Age  Annual_Income  Investment_Amount  \
# 80471  CVHNTKDG02  45.0        19554.0            79724.0
# 79981  CSTII7VZYA  48.0        83671.0           133451.0
# 70453  B9PGQ1I3CB  46.0        60025.0           221994.0
# 72202  BJRUMYEWOQ  22.0        86251.0           182886.0
# 12198  1XWEWUGAI2  45.0        22466.0           112145.0
#
#        Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 80471                 463.0                           118.0
# 79981                 607.0                            42.0
# 70453                 775.0                            66.0
# 72202                 337.0                            50.0
# 12198                 711.0                            74.0
#
#        Number_of_Active_Investments  Potential_Return_Rate  \
# 80471                           2.0                  17.93
# 79981                           NaN                   5.69
# 70453                           1.0                  21.20
# ...

# %% [markdown]
# ### looking at the information about the data

# %%
#data.info()

# %% [markdown]
# ### Checking the null or missing values of data

# %%
#data.isnull().sum()

# %% [markdown]
# ### Checking the data mathematically

# %%
#data.describe()

# %% [markdown]
# ### Checking if there is any duplicate values in entire dataset rows

# %%
#data.duplicated().sum()

# %% [markdown]
# ### Checking the correlation between the cols

# %%
#data.corr(data[5.0]) (outdated!!) now it only works on numeric data
#numeric_data = data.select_dtypes(include=['number'])
#numeric_data.corr()

# %% [markdown]
# for a perticular col to all

# %%
#numeric_data.corr()['Investment_Failed']

# %% [markdown]
# ## Univariate analysis on categorical values

# %%
import seaborn as sns

# %% [markdown]
# ### Count the number of occurances of any category in a col

# %%
#sns.countplot(data['Investment_Failed'])

# %% [markdown]
# ### See the precentages in pie chart for data occurances

# %%
#data['Investment_Sector'].value_counts().plot(kind='pie',autopct='%.2f')

# %% [markdown]
# ## Univariate analysis on Numerical values

# %% [markdown]
# ### Diving the data into groups using Histogram

# %%
import matplotlib.pyplot as plt
#plt.hist(data['Age'],bins=5)

# %% [markdown]
# ### Diving the data into groups for seeing percentages or skewness using Distplot

# %%
#sns.distplot(data['Age'])
# Out:
# <ipython-input-19-ec135ce2bd5e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Finding anonmality in data using boxplot

# %%
#sns.boxplot(data['Age'])

# %% [markdown]
# ## Bivarite/multivariate analysis on 2 or more than 2 values.

# %% [markdown]
# ### scatterplot to plot 2 numeric variables with different color and size to differentiate

# %%
#sns.scatterplot(x=data['Annual_Income'],y=data['Investment_Amount']hue=data['Investment_Failed'],style=data['Has_Investment_Advisor'],size=data['Potential_Return_Rate'])
#this data is not suitable to scatter plot

# %% [markdown]
# ### barplot to plot categorical and numeric values with different color to identify

# %%
#sns.barplot(x=data['Investment_Failed'],y=data['Investment_Amount'],hue=data['Has_Investment_Advisor'])

# %% [markdown]
# ### boxplot to plot categorical and numeric values with different color to identify and anomality

# %%
#sns.boxplot(x=data['Investment_Failed'],y=data['Age'],hue=data['Has_Investment_Advisor'])

# %% [markdown]
# ### distplot to plot categorical and numeric values with different color to identify insights

# %%
#sns.distplot(data[data['Investment_Failed']==0]['Age'],hist=False)
#sns.distplot(data[data['Investment_Failed']==1]['Age'],hist=False)

# %% [markdown]
# ### HeatMap to plot categorical and categorical values with different color to identify insights

# %%
#sns.heatmap(pd.crosstab(data['Investment_Sector'],data['Investment_Failed']))
# Out:
# <Axes: xlabel='Investment_Failed', ylabel='Investment_Sector'>

# %% [markdown]
# ### clustermap to plot categorical and categorical values with different color to identify insights

# %%
#sns.clustermap(pd.crosstab(data['Age'],data['Investment_Failed']))

# %% [markdown]
# ### pairplot to indentify the hidden patterns

# %%
#sns.pairplot(data,hue='Has_Investment_Advisor')
#need much power to execute

# %% [markdown]
# ### Lint plot to plot the date vise data

# %%
#sns.lineplot(x=data['Age'],y=data['Annual_Income'])

# %% [markdown]
# ## Pandas profiling (all of the above insights in one)

# %%
#!pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 74.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 86.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=8316da355f670d42851426d49f16d0350ed37140fade74c55b0dbd458421847d
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
# ...

# %%
#!pip install --upgrade numba

# %%
#!pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 2.0
#     Uninstalling multimethod-2.0:
#       Successfully uninstalled multimethod-2.0
#   Attempting uninstall: imagehash
#     Found existing installation: ImageHash 4.3.2
#     Uninstalling ImageHash-4.3.2:
#       Successfully uninstalled ImageHash-4.3.2
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
#from ydata_profiling import ProfileReport

# Dataset load karein
#data = pd.read_csv('train_data.csv')  # Apne dataset ka path daalein

# Pandas Profiling report generate karein
#profile = ProfileReport(data, title='Pandas Profiling Report', explorative=True)

# Report ko HTML file mein save karein
#profile.to_file('report.html')

# Google Colab mein HTML file download karein
#from google.colab import files
#files.download('report.html')

# %% [markdown]
# ## Feature Selection

# %%
#pd.read_csv('train_data.csv',skip_blank_lines=True,names=['Annual_Income','Investment_Amount','Risk_Tolerance_Score','Months_of_Investing_Experience','Number_of_Active_Investments','Potential_Return_Rate','Investment_Duration','Investment_to_Income_Ratio','Investment_Sector','Has_Investment_Advisor','Investment_Failed'])
data=pd.read_csv('train_data.csv')

data
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 0       0003HW9UAA  51.0            NaN            87300.0
# 1       000ELHLBPV  37.0        81658.0           152598.0
# 2       000G6CHJON   NaN            NaN            77767.0
# 3       000K09D0JB  54.0        42344.0            13261.0
# 4       000NTH4YTU  63.0        48898.0           193990.0
# ...            ...   ...            ...                ...
# 225342  ZZZHT6VWO4  37.0        25394.0                NaN
# 225343  ZZZI5YOV9G  32.0       101616.0           101862.0
# 225344  ZZZMFPZFKE   NaN       102495.0           140375.0
# 225345  ZZZV1HB132  69.0       143661.0           157929.0
# 225346  ZZZX015LV2  65.0       114515.0            95500.0
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 0                        358                              13
# 1                        792                              23
# 2                        359                              57
# ...

# %%
uni=data['Investment_Sector'].unique()
uni
# Out:
# array(['Other', 'Auto', 'Education', 'Business', 'Home'], dtype=object)

# %% [markdown]
# ## Dividing the data into input and output

# %%
inputdata=data.iloc[:,:17]
inputdata
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 0       0003HW9UAA  51.0            NaN            87300.0
# 1       000ELHLBPV  37.0        81658.0           152598.0
# 2       000G6CHJON   NaN            NaN            77767.0
# 3       000K09D0JB  54.0        42344.0            13261.0
# 4       000NTH4YTU  63.0        48898.0           193990.0
# ...            ...   ...            ...                ...
# 225342  ZZZHT6VWO4  37.0        25394.0                NaN
# 225343  ZZZI5YOV9G  32.0       101616.0           101862.0
# 225344  ZZZMFPZFKE   NaN       102495.0           140375.0
# 225345  ZZZV1HB132  69.0       143661.0           157929.0
# 225346  ZZZX015LV2  65.0       114515.0            95500.0
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 0                        358                              13
# 1                        792                              23
# 2                        359                              57
# ...

# %%
outputdata=data.iloc[:,-1:]
outputdata
# Out:
#         Investment_Failed
# 0                       0
# 1                       1
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 225342                  1
# 225343                  1
# 225344                  0
# 225345                  0
# 225346                  0
#
# [225347 rows x 1 columns]

# %% [markdown]
# ## Slpitting the data into train and test

# %%
from sklearn.model_selection import train_test_split
traininput,testinput,trainoutput,testoutput=train_test_split(inputdata,outputdata,test_size=(0.2))
traininput.shape , testinput.shape
# Out:
# ((180277, 17), (45070, 17))

# %% [markdown]
# ## Using ordinal encoding

# %% [markdown]
# this is used when the data in a column has values related to each other since i dont have any such column in my data so i cannot apply it

# %%
#Example code
#from sklearn.preprocessing import OrdinalEncoder
#oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
#oe.fit(X_train)
#X_train = oe.transform(X_train)
#X_test = oe.transform(X_test)

# %% [markdown]
# ## Using lable encoding (only for outputs)

# %%
#It should be only done on output
#from sklearn.preprocessing import LabelEncoder
#encode=LabelEncoder()
#data['Investment_Sector']=encode.fit_transform(data['Investment_Sector'])
#uni
#pd.DataFrame(data)
#data['Has_Investment_Advisor'].replace([True,False],[1,0],inplace=True)
#data
testinput.isnull().sum()
# Out:
# Investor_ID                          0
# Age                               6625
# Annual_Income                     4487
# Investment_Amount                 3709
# Risk_Tolerance_Score                 0
# Months_of_Investing_Experience       0
# Number_of_Active_Investments       885
# Potential_Return_Rate             2224
# Investment_Duration                  0
# Investment_to_Income_Ratio           0
# Education                            0
# Employment_Status                    0
# Marital_Status                    8513
# Owns_Property                        0
# Has_Dependents                       0
# Investment_Sector                    0
# Has_Investment_Advisor             806
# dtype: int64

# %% [markdown]
# ## column transformer used for encoading every column in a single code

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
testinput
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 16276   2L50E970GO  49.0        31019.0             5658.0
# 58560   9CBU3EGQY1  60.0        56515.0           150002.0
# 159657  PJYVIYCE50  35.0        56409.0           226700.0
# 18321   2X2GR93T6X   NaN        17329.0           218929.0
# 217919  YTW357AJJO  50.0        79580.0            13472.0
# ...            ...   ...            ...                ...
# 13757   26HBB4UUJ2  55.0            NaN           152158.0
# 75917   C5ELG7PX1M  58.0        51586.0            79413.0
# 88339   E5G1RRCFSG   NaN        42573.0                NaN
# 20996   3D4GDSRQSF   NaN        65929.0           152719.0
# 34992   5LQU273Q8P  60.0       104614.0                NaN
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 16276                    327                             108
# 58560                   1086                              78
# 159657                   664                              96
# ...

# %% [markdown]
# ## Scaling the input values

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
#learning the training data
scale.fit(traininput)
#scaling the test input and transforming it squeezing it
testinput=scale.transform(testinput)
#scaling the train input and transforming it squeezing it
tratraininput=scale.transform(traininput)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-0e06bc0f397b> in <cell line: 0>()
#       1 #learning the training data
# ----> 2 scale.fit(traininput)
#       3 #scaling the test input and transforming it squeezing it
#       4 testinput=scale.transform(testinput)
#       5 #scaling the train input and transforming it squeezing it
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#     895
#     896     @_fit_context(prefer_skip_nested_validation=True)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# ...

# %%
traininput
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 12964   220WS10TLS  38.0        26331.0           137368.0
# 76935   CB1HVEL1X4   NaN        63181.0           175756.0
# 89077   E9MP9IK0S8  57.0            NaN            23310.0
# 153927  OMX5YXQX6P  58.0        16622.0           158683.0
# 88182   E4LX5PJ4FF  44.0        41270.0            45024.0
# ...            ...   ...            ...                ...
# 160583  PPH7N05LEF  63.0       149556.0           144305.0
# 159979  PLUIAV1YIS  65.0        21609.0            48624.0
# 51808   8ANXUGS5SZ  46.0       148756.0           242109.0
# 172643  RM9QCVUDDS  57.0        40076.0           244476.0
# 38551   66IZE6Y0Z2  30.0        83582.0             9464.0
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 12964                   1074                               9
# 76935                    502                              75
# 89077                    408                              22
# ...

# %%
traininput = pd.DataFrame(traininput, columns=traininput.columns)
traininput

testinput=  pd.DataFrame(testinput, columns=testinput.columns)
testinput
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 16276   2L50E970GO  49.0        31019.0             5658.0
# 58560   9CBU3EGQY1  60.0        56515.0           150002.0
# 159657  PJYVIYCE50  35.0        56409.0           226700.0
# 18321   2X2GR93T6X   NaN        17329.0           218929.0
# 217919  YTW357AJJO  50.0        79580.0            13472.0
# ...            ...   ...            ...                ...
# 13757   26HBB4UUJ2  55.0            NaN           152158.0
# 75917   C5ELG7PX1M  58.0        51586.0            79413.0
# 88339   E5G1RRCFSG   NaN        42573.0                NaN
# 20996   3D4GDSRQSF   NaN        65929.0           152719.0
# 34992   5LQU273Q8P  60.0       104614.0                NaN
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 16276                    327                             108
# 58560                   1086                              78
# 159657                   664                              96
# ...

# %%
np.round(traininput.describe(),1)
# Out:
#             Age  Annual_Income  Investment_Amount  Risk_Tolerance_Score  \
# count  154062.0       162138.0           165953.0              180277.0
# mean       46.0        82799.2           127116.1                 599.0
# std        19.1        38874.4            70790.1                 186.5
# min        18.0        15000.0             5005.0                 300.0
# 25%        31.0        49245.0            65631.0                 445.0
# 50%        45.0        82975.0           126950.0                 590.0
# 75%        58.0       116383.5           188205.0                 735.0
# max       119.0       149999.0           249999.0                1099.0
#
#        Months_of_Investing_Experience  Number_of_Active_Investments  \
# count                        180277.0                      176650.0
# mean                             59.8                           2.5
# std                              34.6                           1.1
# ...

# %% [markdown]
# ## Logistic regresion algorithm

# %%
from sklearn.linear_model import LogisticRegression

# %%
logic=LogisticRegression()

# %%
logic.fit(traininput,trainoutput)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-c3559b422333> in <cell line: 0>()
# ----> 1 logic.fit(traininput,trainoutput)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
predict=logic.predict(testinput)

# %%
predict

# %%
testoutput

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(predict,testoutput)*100
print(round(accuracy,2), '%')
